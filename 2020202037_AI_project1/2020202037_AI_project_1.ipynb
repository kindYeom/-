# %% [markdown]
# # PCA

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_lfw_people
from sklearn.model_selection import train_test_split

# %%
class PCA:
    def __init__(self, n_components, whiten, random_state=41, gram_iter=100):
        self.n_components = n_components
        self.whiten = whiten
        self.gram_iter = gram_iter
        
    def covariance(self,data): # clear
        mean = np.mean(data,axis = 0)

        centered_data = data - mean

        cov = np.dot(centered_data.T, centered_data) / (centered_data.shape[0] - 1)

        return cov

    def max_off_diagonal(self, matrix):
        # 대각 성분을 제외한 절대값의 최대값을 찾는 함수
        no_diag_matrix = matrix.copy()  # 원본 행렬을 복사

        # 대각 성분을 0으로 설정
        np.fill_diagonal(no_diag_matrix, 0)

        # 대각 성분을 제외한 절대값의 최대값 반환
        return np.max(np.abs(no_diag_matrix))


    def whitening(self, data):
        """데이터를 whiten 변환 (평균 제거 후 표준편차로 나누기)"""
        mean = np.mean(data, axis=0)  # 각 특징의 평균 계산
        std_dev = np.std(data, axis=0)  # 각 특징의 표준편차 계산

        # 표준편차가 0인 경우 1로 설정 (0으로 나누는 것을 방지하기 위해)
        std_dev[std_dev == 0] = 1

        # Whitening 변환 적용
        whitened_data = (data - mean) / std_dev

        return whitened_data

    def gram_schmidt(self, matrix):
        """Gram-Schmidt 과정을 통해 Q와 R을 동시에 구하는 함수"""
        n_vectors = matrix.shape[1]  # 열 벡터의 개수
        Q = np.zeros_like(matrix)  # 직교 기저를 저장할 행렬
        R = np.zeros((n_vectors, n_vectors), dtype=np.float64)  # R 행렬

        for i in range(n_vectors):
            # 처음에는 주어진 벡터를 그대로 사용
            q_i = matrix[:, i]

            # 이전 기저들에 대한 정사영을 빼줌
            for j in range(i):
                q_j = Q[:, j]
                R[j, i] = np.dot(q_j, matrix[:, i])  # R[j, i]를 정사영으로 저장
                q_i -= R[j, i] * q_j  # q_i에서 정사영을 빼줌

            # 직교화된 벡터를 Q 행렬의 i번째 열에 추가
            R[i, i] = np.linalg.norm(q_i)  # R[i, i]는 q_i의 노름
            Q[:, i] = q_i / R[i, i]  # 정규화하여 단위 벡터로 만듦

        return Q, R
    
    def eig(self, data, max_iter=200):
        """QR 알고리즘을 통해 고유값과 고유벡터를 추출하는 함수"""
        # 공분산 행렬 계산
        cov_matrix = self.covariance(data)

        # QR 분해 초기화
        A = cov_matrix.copy()
        n = A.shape[0]
        Q_total = np.eye(n)  # 고유벡터들을 저장할 행렬

        for i in range(max_iter):
            # QR 분해 수행
            Q, R = self.gram_schmidt(A)

            # 행렬 갱신 (R * Q)
            A = np.dot(R, Q)

            # 고유벡터 계산을 위해 Q 행렬을 누적
            Q_total = np.dot(Q_total, Q)

            max_off_diag = self.max_off_diagonal(A)
            print(f"Iteration {i}, 대각 성분 제외 최대값: {max_off_diag}")

        # 대각 성분들이 고유값, Q_total이 고유벡터
        eigenvalues = np.diag(A)
        eigenvectors = Q_total

        return eigenvalues, eigenvectors

    
    def fit(self, data):
        # 1. 공분산 행렬을 기반으로 QR 알고리즘을 사용해 고유값과 고유벡터를 추출
        eigenvalues, eigenvectors = self.eig(data)

        # 2. 고유값을 크기순으로 정렬하여 상위 n개의 고유값과 고유벡터를 선택
        idx = np.argsort(eigenvalues)[::-1] # 고유값을 내림차순으로 정렬
        eigenvalues = eigenvalues[idx]
        eigenvectors = eigenvectors[:, idx]

        # 3. 상위 n개의 고유값 및 고유벡터 선택
        self.components_ = eigenvectors[:, :self.n_components]
        self.explained_variance_ = eigenvalues[:self.n_components]

        # 4. Whitening 옵션이 켜져 있을 경우 고유벡터를 whitening 처리
        if self.whiten:
            self.components_ = self.whitening(self.components_)  # whitening 처리

        # 5. 최종적으로 pca_output 계산
        pca_output = np.dot(data, self.components_)

        # 6. PCA 결과를 반환
        return pca_output

# %%
people = fetch_lfw_people(min_faces_per_person=100, resize=0.3)
image_shape = people.images[0].shape
print("dataset keys        : ", people.keys())
print("dataset.images shape: ", people.images.shape)
print("dataset.data shape  : ", people.data.shape)
print("dataset.target shape: ", people.target.shape)
# Out:
# dataset keys        :  dict_keys(['data', 'images', 'target', 'target_names', 'DESCR'])
# dataset.images shape:  (607, 37, 28)
# dataset.data shape  :  (607, 1036)
# dataset.target shape:  (607,)

# %%
pca = PCA(200, False)
n_component_data = pca.fit(people.data)
pca_w = PCA(200, True)
n_component_data_w = pca_w.fit(people.data)
X_train, X_test, y_train, y_test = train_test_split(n_component_data, people.target, test_size=0.25, random_state=41)
X_train_w, X_test_w, y_train_w, y_test_w = train_test_split(n_component_data_w, people.target, test_size=0.25, random_state=41)
# Out:
# Iteration 0, 대각 성분 제외 최대값: 1.9492193615110616
# Iteration 1, 대각 성분 제외 최대값: 2.6235733292113106
# Iteration 2, 대각 성분 제외 최대값: 2.585466796626074
# Iteration 3, 대각 성분 제외 최대값: 2.2147283135538696
# Iteration 4, 대각 성분 제외 최대값: 2.374682166844347
# Iteration 5, 대각 성분 제외 최대값: 3.010636667577677
# Iteration 6, 대각 성분 제외 최대값: 2.3358231045344002
# Iteration 7, 대각 성분 제외 최대값: 3.290161863594888
# Iteration 8, 대각 성분 제외 최대값: 2.6510149455988534
# Iteration 9, 대각 성분 제외 최대값: 3.245013202903191
# Iteration 10, 대각 성분 제외 최대값: 2.8557918040484243
# Iteration 11, 대각 성분 제외 최대값: 3.1430982259138296
# Iteration 12, 대각 성분 제외 최대값: 2.9741578953763783
# Iteration 13, 대각 성분 제외 최대값: 2.971833025439469
# Iteration 14, 대각 성분 제외 최대값: 3.034410720021142
# Iteration 15, 대각 성분 제외 최대값: 2.659736664354426
# Iteration 16, 대각 성분 제외 최대값: 3.046092180064177
# Iteration 17, 대각 성분 제외 최대값: 2.6732023147724924
# Iteration 18, 대각 성분 제외 최대값: 3.0176902021568877
# Iteration 19, 대각 성분 제외 최대값: 2.7905679829910017
# Iteration 20, 대각 성분 제외 최대값: 2.959249828633449
# Iteration 21, 대각 성분 제외 최대값: 2.83952630467725
# Iteration 22, 대각 성분 제외 최대값: 2.881225562076878
# Iteration 23, 대각 성분 제외 최대값: 2.8401050406149717
# Iteration 24, 대각 성분 제외 최대값: 2.792926279799285
# Iteration 25, 대각 성분 제외 최대값: 2.8085701256130577
# Iteration 26, 대각 성분 제외 최대값: 2.701628549700535
# Iteration 27, 대각 성분 제외 최대값: 2.7571596598109585
# Iteration 28, 대각 성분 제외 최대값: 2.6124244609631746
# Iteration 29, 대각 성분 제외 최대값: 2.6947299053590568
# Iteration 30, 대각 성분 제외 최대값: 2.528514887050959
# Iteration 31, 대각 성분 제외 최대값: 2.6275170759814643
# Iteration 32, 대각 성분 제외 최대값: 2.45166097499434
# Iteration 33, 대각 성분 제외 최대값: 2.559786216594023
# Iteration 34, 대각 성분 제외 최대값: 2.3826179261021956
# Iteration 35, 대각 성분 제외 최대값: 2.4943425863335227
# Iteration 36, 대각 성분 제외 최대값: 2.321485256929391
# Iteration 37, 대각 성분 제외 최대값: 2.4329242765073236
# Iteration 38, 대각 성분 제외 최대값: 2.2679629279873823
# Iteration 39, 대각 성분 제외 최대값: 2.3765035143198174
# Iteration 40, 대각 성분 제외 최대값: 2.221526308642575
# Iteration 41, 대각 성분 제외 최대값: 2.3255156421480607
# Iteration 42, 대각 성분 제외 최대값: 2.2055588392352212
# Iteration 43, 대각 성분 제외 최대값: 2.280030337294391
# Iteration 44, 대각 성분 제외 최대값: 2.270486140235772
# Iteration 45, 대각 성분 제외 최대값: 2.312439250853061
# Iteration 46, 대각 성분 제외 최대값: 2.321153833730605
# Iteration 47, 대각 성분 제외 최대값: 2.3781645395567446
# Iteration 48, 대각 성분 제외 최대값: 2.358569522457491
# Iteration 49, 대각 성분 제외 최대값: 2.434302995010383
# Iteration 50, 대각 성분 제외 최대값: 2.383511768421651
# Iteration 51, 대각 성분 제외 최대값: 2.4790379228469264
# Iteration 52, 대각 성분 제외 최대값: 2.3965772771316844
# Iteration 53, 대각 성분 제외 최대값: 2.5109207656143795
# Iteration 54, 대각 성분 제외 최대값: 2.3982148604757256
# Iteration 55, 대각 성분 제외 최대값: 2.5288237123281205
# Iteration 56, 대각 성분 제외 최대값: 2.3887454424681525
# Iteration 57, 대각 성분 제외 최대값: 2.531849230878874
# Iteration 58, 대각 성분 제외 최대값: 2.3683659476517644
# Iteration 59, 대각 성분 제외 최대값: 2.5192186094850593
# Iteration 60, 대각 성분 제외 최대값: 2.337142947307757
# Iteration 61, 대각 성분 제외 최대값: 2.490159221352248
# Iteration 62, 대각 성분 제외 최대값: 2.294999650582826
# Iteration 63, 대각 성분 제외 최대값: 2.443809977196807
# Iteration 64, 대각 성분 제외 최대값: 2.2416994231958847
# Iteration 65, 대각 성분 제외 최대값: 2.379154334950766
# Iteration 66, 대각 성분 제외 최대값: 2.2200744799234884
# Iteration 67, 대각 성분 제외 최대값: 2.3587301501664295
# Iteration 68, 대각 성분 제외 최대값: 2.3375340374556015
# Iteration 69, 대각 성분 제외 최대값: 2.5328179561221367
# Iteration 70, 대각 성분 제외 최대값: 2.456276884545606
# Iteration 71, 대각 성분 제외 최대값: 2.708109679138604
# Iteration 72, 대각 성분 제외 최대값: 2.574846243944036
# Iteration 73, 대각 성분 제외 최대값: 2.880307338788494
# Iteration 74, 대각 성분 제외 최대값: 2.6913137175835002
# Iteration 75, 대각 성분 제외 최대값: 3.0436719980555442
# Iteration 76, 대각 성분 제외 최대값: 2.8033294040289833
# Iteration 77, 대각 성분 제외 최대값: 3.191608589081334
# Iteration 78, 대각 성분 제외 최대값: 2.9082226406603153
# Iteration 79, 대각 성분 제외 최대값: 3.317594979911272
# Iteration 80, 대각 성분 제외 최대값: 3.0031703328445736
# Iteration 81, 대각 성분 제외 최대값: 3.4162764111655477
# Iteration 82, 대각 성분 제외 최대값: 3.085432335473324
# Iteration 83, 대각 성분 제외 최대값: 3.484408929613565
# Iteration 84, 대각 성분 제외 최대값: 3.152630124470664
# Iteration 85, 대각 성분 제외 최대값: 3.5213386208450235
# Iteration 86, 대각 성분 제외 최대값: 3.2030219411929552
# Iteration 87, 대각 성분 제외 최대값: 3.5288787581081618
# Iteration 88, 대각 성분 제외 최대값: 3.235714600139569
# Iteration 89, 대각 성분 제외 최대값: 3.5106920408717026
# Iteration 90, 대각 성분 제외 최대값: 3.2507603733416395
# Iteration 91, 대각 성분 제외 최대값: 3.4714501392580144
# Iteration 92, 대각 성분 제외 최대값: 3.249117505651001
# Iteration 93, 대각 성분 제외 최대값: 3.4160443774728932
# Iteration 94, 대각 성분 제외 최대값: 3.2324862994056693
# Iteration 95, 대각 성분 제외 최대값: 3.349012946148498
# Iteration 96, 대각 성분 제외 최대값: 3.2030680237810554
# Iteration 97, 대각 성분 제외 최대값: 3.2742231811907385
# Iteration 98, 대각 성분 제외 최대값: 3.16330161194841
# Iteration 99, 대각 성분 제외 최대값: 3.1947644815308927
# Iteration 100, 대각 성분 제외 최대값: 3.115628699343733
# Iteration 101, 대각 성분 제외 최대값: 3.1129780202868162
# Iteration 102, 대각 성분 제외 최대값: 3.0623160436384436
# Iteration 103, 대각 성분 제외 최대값: 3.030556441091741
# Iteration 104, 대각 성분 제외 최대값: 3.0053442496355482
# Iteration 105, 대각 성분 제외 최대값: 2.948666718843533
# Iteration 106, 대각 성분 제외 최대값: 2.946357010624613
# Iteration 107, 대각 성분 제외 최대값: 2.8680697150572625
# Iteration 108, 대각 성분 제외 최대값: 2.886655002669806
# Iteration 109, 대각 성분 제외 최대값: 2.789223128074276
# Iteration 110, 대각 성분 제외 최대값: 2.827220493776842
# Iteration 111, 대각 성분 제외 최대값: 2.7123650691104424
# Iteration 112, 대각 성분 제외 최대값: 2.768756734305842
# Iteration 113, 대각 성분 제외 최대값: 2.6375787524093153
# Iteration 114, 대각 성분 제외 최대값: 2.7117340610755503
# Iteration 115, 대각 성분 제외 최대값: 2.5648412545647767
# Iteration 116, 대각 성분 제외 최대값: 2.65643425842237
# Iteration 117, 대각 성분 제외 최대값: 2.4940586998515513
# Iteration 118, 대각 성분 제외 최대값: 2.6029914810293553
# Iteration 119, 대각 성분 제외 최대값: 2.4853248907485614
# Iteration 120, 대각 성분 제외 최대값: 2.551427047323201
# Iteration 121, 대각 성분 제외 최대값: 2.545439351735529
# Iteration 122, 대각 성분 제외 최대값: 2.5016779653614325
# Iteration 123, 대각 성분 제외 최대값: 2.599216808234052
# Iteration 124, 대각 성분 제외 최대값: 2.5626776430306593
# Iteration 125, 대각 성분 제외 최대값: 2.647435955656529
# Iteration 126, 대각 성분 제외 최대값: 2.6175543613266377
# Iteration 127, 대각 성분 제외 최대값: 2.6907730914697012
# Iteration 128, 대각 성분 제외 최대값: 2.6663071132269556
# Iteration 129, 대각 성분 제외 최대값: 2.7298147415948772
# Iteration 130, 대각 성분 제외 최대값: 2.709725099904425
# Iteration 131, 대각 성분 제외 최대값: 2.7650693824530834
# Iteration 132, 대각 성분 제외 최대값: 2.7484924950086556
# Iteration 133, 대각 성분 제외 최대값: 2.7969780213255153
# Iteration 134, 대각 성분 제외 최대값: 2.78320057392455
# Iteration 135, 대각 성분 제외 최대값: 2.8259235308135127
# Iteration 136, 대각 성분 제외 최대값: 2.8143594523684388
# Iteration 137, 대각 성분 제외 최대값: 2.852238788756145
# Iteration 138, 대각 성분 제외 최대값: 2.84240894185525
# Iteration 139, 대각 성분 제외 최대값: 2.876213708132927
# Iteration 140, 대각 성분 제외 최대값: 2.867728302026895
# Iteration 141, 대각 성분 제외 최대값: 2.898101278457284
# Iteration 142, 대각 성분 제외 최대값: 2.8906448335171575
# Iteration 143, 대각 성분 제외 최대값: 2.9181227360719295
# Iteration 144, 대각 성분 제외 최대값: 2.911441349402512
# Iteration 145, 대각 성분 제외 최대값: 2.936471979615762
# Iteration 146, 대각 성분 제외 최대값: 2.930362613131628
# Iteration 147, 대각 성분 제외 최대값: 2.9533193368508077
# Iteration 148, 대각 성분 제외 최대값: 2.9476208516875144
# Iteration 149, 대각 성분 제외 최대값: 2.968814777405448
# Iteration 150, 대각 성분 제외 최대값: 2.9634004576226984
# Iteration 151, 대각 성분 제외 최대값: 2.9830906540551894
# Iteration 152, 대각 성분 제외 최대값: 2.9778619892073888
# Iteration 153, 대각 성분 제외 최대값: 2.996264043801888
# Iteration 154, 대각 성분 제외 최대값: 2.991145568846266
# Iteration 155, 대각 성분 제외 최대값: 3.0084387496714924
# Iteration 156, 대각 성분 제외 최대값: 3.0033737689065636
# Iteration 157, 대각 성분 제외 최대값: 3.019707014997746
# Iteration 158, 대각 성분 제외 최대값: 3.0146540627542087
# Iteration 159, 대각 성분 제외 최대값: 3.030150994006994
# Iteration 160, 대각 성분 제외 최대값: 3.0250809079882153
# Iteration 161, 대각 성분 제외 최대값: 3.039844015696068
# Iteration 162, 대각 성분 제외 최대값: 3.034737519025138
# Iteration 163, 대각 성분 제외 최대값: 3.048851672191473
# Iteration 164, 대각 성분 제외 최대값: 3.043697377480577
# Iteration 165, 대각 성분 제외 최대값: 3.057232757870304
# Iteration 166, 대각 성분 제외 최대값: 3.0520255212374834
# Iteration 167, 대각 성분 제외 최대값: 3.0650400813899443
# Iteration 168, 대각 성분 제외 최대값: 3.0597796466152256
# Iteration 169, 대각 성분 제외 최대값: 3.0723211693007966
# Iteration 170, 대각 성분 제외 최대값: 3.0670110525542698
# Iteration 171, 대각 성분 제외 최대값: 3.079118877003196
# Iteration 172, 대각 성분 제외 최대값: 3.0737654510911336
# Iteration 173, 대각 성분 제외 최대값: 3.0854719203672496
# Iteration 174, 대각 성분 제외 최대값: 3.0800836644998544
# Iteration 175, 대각 성분 제외 최대값: 3.0914153392868218
# Iteration 176, 대각 성분 제외 최대값: 3.0860022262102262
# Iteration 177, 대각 성분 제외 최대값: 3.096980902721457
# Iteration 178, 대각 성분 제외 최대값: 3.0915538998819545
# Iteration 179, 대각 성분 제외 최대값: 3.1021974633383307
# Iteration 180, 대각 성분 제외 최대값: 3.0967681287320903
# Iteration 181, 대각 성분 제외 최대값: 3.1070912686547203
# Iteration 182, 대각 성분 제외 최대값: 3.1016714253072535
# Iteration 183, 대각 성분 제외 최대값: 3.111686234561783
# Iteration 184, 대각 성분 제외 최대값: 3.1062877102997373
# Iteration 185, 대각 성분 제외 최대값: 3.1160041862510353
# Iteration 186, 대각 성분 제외 최대값: 3.1106386076756793
# Iteration 187, 대각 성분 제외 최대값: 3.120065070839329
# Iteration 188, 대각 성분 제외 최대값: 3.1147437022692053
# Iteration 189, 대각 성분 제외 최대값: 3.123887145374507
# Iteration 190, 대각 성분 제외 최대값: 3.1186207650634903
# Iteration 191, 대각 성분 제외 최대값: 3.127487143384057
# Iteration 192, 대각 성분 제외 최대값: 3.1222859505962606
# Iteration 193, 대각 성분 제외 최대값: 3.1308804226876865
# Iteration 194, 대각 성분 제외 최대값: 3.1257539702692774
# Iteration 195, 대각 성분 제외 최대값: 3.1340810968195707
# Iteration 196, 대각 성분 제외 최대값: 3.1290382447873086
# Iteration 197, 대각 성분 제외 최대값: 3.137102152086156
# Iteration 198, 대각 성분 제외 최대값: 3.1321510384846882
# Iteration 199, 대각 성분 제외 최대값: 3.1399555520124602
# Iteration 0, 대각 성분 제외 최대값: 1.9492193615110616
# Iteration 1, 대각 성분 제외 최대값: 2.6235733292113106
# Iteration 2, 대각 성분 제외 최대값: 2.585466796626074
# Iteration 3, 대각 성분 제외 최대값: 2.2147283135538696
# Iteration 4, 대각 성분 제외 최대값: 2.374682166844347
# Iteration 5, 대각 성분 제외 최대값: 3.010636667577677
# Iteration 6, 대각 성분 제외 최대값: 2.3358231045344002
# Iteration 7, 대각 성분 제외 최대값: 3.290161863594888
# Iteration 8, 대각 성분 제외 최대값: 2.6510149455988534
# Iteration 9, 대각 성분 제외 최대값: 3.245013202903191
# Iteration 10, 대각 성분 제외 최대값: 2.8557918040484243
# Iteration 11, 대각 성분 제외 최대값: 3.1430982259138296
# Iteration 12, 대각 성분 제외 최대값: 2.9741578953763783
# Iteration 13, 대각 성분 제외 최대값: 2.971833025439469
# Iteration 14, 대각 성분 제외 최대값: 3.034410720021142
# Iteration 15, 대각 성분 제외 최대값: 2.659736664354426
# Iteration 16, 대각 성분 제외 최대값: 3.046092180064177
# Iteration 17, 대각 성분 제외 최대값: 2.6732023147724924
# Iteration 18, 대각 성분 제외 최대값: 3.0176902021568877
# Iteration 19, 대각 성분 제외 최대값: 2.7905679829910017
# Iteration 20, 대각 성분 제외 최대값: 2.959249828633449
# Iteration 21, 대각 성분 제외 최대값: 2.83952630467725
# Iteration 22, 대각 성분 제외 최대값: 2.881225562076878
# Iteration 23, 대각 성분 제외 최대값: 2.8401050406149717
# Iteration 24, 대각 성분 제외 최대값: 2.792926279799285
# Iteration 25, 대각 성분 제외 최대값: 2.8085701256130577
# Iteration 26, 대각 성분 제외 최대값: 2.701628549700535
# Iteration 27, 대각 성분 제외 최대값: 2.7571596598109585
# Iteration 28, 대각 성분 제외 최대값: 2.6124244609631746
# Iteration 29, 대각 성분 제외 최대값: 2.6947299053590568
# Iteration 30, 대각 성분 제외 최대값: 2.528514887050959
# Iteration 31, 대각 성분 제외 최대값: 2.6275170759814643
# Iteration 32, 대각 성분 제외 최대값: 2.45166097499434
# Iteration 33, 대각 성분 제외 최대값: 2.559786216594023
# Iteration 34, 대각 성분 제외 최대값: 2.3826179261021956
# Iteration 35, 대각 성분 제외 최대값: 2.4943425863335227
# Iteration 36, 대각 성분 제외 최대값: 2.321485256929391
# Iteration 37, 대각 성분 제외 최대값: 2.4329242765073236
# Iteration 38, 대각 성분 제외 최대값: 2.2679629279873823
# Iteration 39, 대각 성분 제외 최대값: 2.3765035143198174
# Iteration 40, 대각 성분 제외 최대값: 2.221526308642575
# Iteration 41, 대각 성분 제외 최대값: 2.3255156421480607
# Iteration 42, 대각 성분 제외 최대값: 2.2055588392352212
# Iteration 43, 대각 성분 제외 최대값: 2.280030337294391
# Iteration 44, 대각 성분 제외 최대값: 2.270486140235772
# Iteration 45, 대각 성분 제외 최대값: 2.312439250853061
# Iteration 46, 대각 성분 제외 최대값: 2.321153833730605
# Iteration 47, 대각 성분 제외 최대값: 2.3781645395567446
# Iteration 48, 대각 성분 제외 최대값: 2.358569522457491
# Iteration 49, 대각 성분 제외 최대값: 2.434302995010383
# Iteration 50, 대각 성분 제외 최대값: 2.383511768421651
# Iteration 51, 대각 성분 제외 최대값: 2.4790379228469264
# Iteration 52, 대각 성분 제외 최대값: 2.3965772771316844
# Iteration 53, 대각 성분 제외 최대값: 2.5109207656143795
# Iteration 54, 대각 성분 제외 최대값: 2.3982148604757256
# Iteration 55, 대각 성분 제외 최대값: 2.5288237123281205
# Iteration 56, 대각 성분 제외 최대값: 2.3887454424681525
# Iteration 57, 대각 성분 제외 최대값: 2.531849230878874
# Iteration 58, 대각 성분 제외 최대값: 2.3683659476517644
# Iteration 59, 대각 성분 제외 최대값: 2.5192186094850593
# Iteration 60, 대각 성분 제외 최대값: 2.337142947307757
# Iteration 61, 대각 성분 제외 최대값: 2.490159221352248
# Iteration 62, 대각 성분 제외 최대값: 2.294999650582826
# Iteration 63, 대각 성분 제외 최대값: 2.443809977196807
# Iteration 64, 대각 성분 제외 최대값: 2.2416994231958847
# Iteration 65, 대각 성분 제외 최대값: 2.379154334950766
# Iteration 66, 대각 성분 제외 최대값: 2.2200744799234884
# Iteration 67, 대각 성분 제외 최대값: 2.3587301501664295
# Iteration 68, 대각 성분 제외 최대값: 2.3375340374556015
# Iteration 69, 대각 성분 제외 최대값: 2.5328179561221367
# Iteration 70, 대각 성분 제외 최대값: 2.456276884545606
# Iteration 71, 대각 성분 제외 최대값: 2.708109679138604
# Iteration 72, 대각 성분 제외 최대값: 2.574846243944036
# Iteration 73, 대각 성분 제외 최대값: 2.880307338788494
# Iteration 74, 대각 성분 제외 최대값: 2.6913137175835002
# Iteration 75, 대각 성분 제외 최대값: 3.0436719980555442
# Iteration 76, 대각 성분 제외 최대값: 2.8033294040289833
# Iteration 77, 대각 성분 제외 최대값: 3.191608589081334
# Iteration 78, 대각 성분 제외 최대값: 2.9082226406603153
# Iteration 79, 대각 성분 제외 최대값: 3.317594979911272
# Iteration 80, 대각 성분 제외 최대값: 3.0031703328445736
# Iteration 81, 대각 성분 제외 최대값: 3.4162764111655477
# Iteration 82, 대각 성분 제외 최대값: 3.085432335473324
# Iteration 83, 대각 성분 제외 최대값: 3.484408929613565
# Iteration 84, 대각 성분 제외 최대값: 3.152630124470664
# Iteration 85, 대각 성분 제외 최대값: 3.5213386208450235
# Iteration 86, 대각 성분 제외 최대값: 3.2030219411929552
# Iteration 87, 대각 성분 제외 최대값: 3.5288787581081618
# Iteration 88, 대각 성분 제외 최대값: 3.235714600139569
# Iteration 89, 대각 성분 제외 최대값: 3.5106920408717026
# Iteration 90, 대각 성분 제외 최대값: 3.2507603733416395
# Iteration 91, 대각 성분 제외 최대값: 3.4714501392580144
# Iteration 92, 대각 성분 제외 최대값: 3.249117505651001
# Iteration 93, 대각 성분 제외 최대값: 3.4160443774728932
# Iteration 94, 대각 성분 제외 최대값: 3.2324862994056693
# Iteration 95, 대각 성분 제외 최대값: 3.349012946148498
# Iteration 96, 대각 성분 제외 최대값: 3.2030680237810554
# Iteration 97, 대각 성분 제외 최대값: 3.2742231811907385
# Iteration 98, 대각 성분 제외 최대값: 3.16330161194841
# Iteration 99, 대각 성분 제외 최대값: 3.1947644815308927
# Iteration 100, 대각 성분 제외 최대값: 3.115628699343733
# Iteration 101, 대각 성분 제외 최대값: 3.1129780202868162
# Iteration 102, 대각 성분 제외 최대값: 3.0623160436384436
# Iteration 103, 대각 성분 제외 최대값: 3.030556441091741
# Iteration 104, 대각 성분 제외 최대값: 3.0053442496355482
# Iteration 105, 대각 성분 제외 최대값: 2.948666718843533
# Iteration 106, 대각 성분 제외 최대값: 2.946357010624613
# Iteration 107, 대각 성분 제외 최대값: 2.8680697150572625
# Iteration 108, 대각 성분 제외 최대값: 2.886655002669806
# Iteration 109, 대각 성분 제외 최대값: 2.789223128074276
# Iteration 110, 대각 성분 제외 최대값: 2.827220493776842
# Iteration 111, 대각 성분 제외 최대값: 2.7123650691104424
# Iteration 112, 대각 성분 제외 최대값: 2.768756734305842
# Iteration 113, 대각 성분 제외 최대값: 2.6375787524093153
# Iteration 114, 대각 성분 제외 최대값: 2.7117340610755503
# Iteration 115, 대각 성분 제외 최대값: 2.5648412545647767
# Iteration 116, 대각 성분 제외 최대값: 2.65643425842237
# Iteration 117, 대각 성분 제외 최대값: 2.4940586998515513
# Iteration 118, 대각 성분 제외 최대값: 2.6029914810293553
# Iteration 119, 대각 성분 제외 최대값: 2.4853248907485614
# Iteration 120, 대각 성분 제외 최대값: 2.551427047323201
# Iteration 121, 대각 성분 제외 최대값: 2.545439351735529
# Iteration 122, 대각 성분 제외 최대값: 2.5016779653614325
# Iteration 123, 대각 성분 제외 최대값: 2.599216808234052
# Iteration 124, 대각 성분 제외 최대값: 2.5626776430306593
# Iteration 125, 대각 성분 제외 최대값: 2.647435955656529
# Iteration 126, 대각 성분 제외 최대값: 2.6175543613266377
# Iteration 127, 대각 성분 제외 최대값: 2.6907730914697012
# Iteration 128, 대각 성분 제외 최대값: 2.6663071132269556
# Iteration 129, 대각 성분 제외 최대값: 2.7298147415948772
# Iteration 130, 대각 성분 제외 최대값: 2.709725099904425
# Iteration 131, 대각 성분 제외 최대값: 2.7650693824530834
# Iteration 132, 대각 성분 제외 최대값: 2.7484924950086556
# Iteration 133, 대각 성분 제외 최대값: 2.7969780213255153
# Iteration 134, 대각 성분 제외 최대값: 2.78320057392455
# Iteration 135, 대각 성분 제외 최대값: 2.8259235308135127
# Iteration 136, 대각 성분 제외 최대값: 2.8143594523684388
# Iteration 137, 대각 성분 제외 최대값: 2.852238788756145
# Iteration 138, 대각 성분 제외 최대값: 2.84240894185525
# Iteration 139, 대각 성분 제외 최대값: 2.876213708132927
# Iteration 140, 대각 성분 제외 최대값: 2.867728302026895
# Iteration 141, 대각 성분 제외 최대값: 2.898101278457284
# Iteration 142, 대각 성분 제외 최대값: 2.8906448335171575
# Iteration 143, 대각 성분 제외 최대값: 2.9181227360719295
# Iteration 144, 대각 성분 제외 최대값: 2.911441349402512
# Iteration 145, 대각 성분 제외 최대값: 2.936471979615762
# Iteration 146, 대각 성분 제외 최대값: 2.930362613131628
# Iteration 147, 대각 성분 제외 최대값: 2.9533193368508077
# Iteration 148, 대각 성분 제외 최대값: 2.9476208516875144
# Iteration 149, 대각 성분 제외 최대값: 2.968814777405448
# Iteration 150, 대각 성분 제외 최대값: 2.9634004576226984
# Iteration 151, 대각 성분 제외 최대값: 2.9830906540551894
# Iteration 152, 대각 성분 제외 최대값: 2.9778619892073888
# Iteration 153, 대각 성분 제외 최대값: 2.996264043801888
# Iteration 154, 대각 성분 제외 최대값: 2.991145568846266
# Iteration 155, 대각 성분 제외 최대값: 3.0084387496714924
# Iteration 156, 대각 성분 제외 최대값: 3.0033737689065636
# Iteration 157, 대각 성분 제외 최대값: 3.019707014997746
# Iteration 158, 대각 성분 제외 최대값: 3.0146540627542087
# Iteration 159, 대각 성분 제외 최대값: 3.030150994006994
# Iteration 160, 대각 성분 제외 최대값: 3.0250809079882153
# Iteration 161, 대각 성분 제외 최대값: 3.039844015696068
# Iteration 162, 대각 성분 제외 최대값: 3.034737519025138
# Iteration 163, 대각 성분 제외 최대값: 3.048851672191473
# Iteration 164, 대각 성분 제외 최대값: 3.043697377480577
# Iteration 165, 대각 성분 제외 최대값: 3.057232757870304
# Iteration 166, 대각 성분 제외 최대값: 3.0520255212374834
# Iteration 167, 대각 성분 제외 최대값: 3.0650400813899443
# Iteration 168, 대각 성분 제외 최대값: 3.0597796466152256
# Iteration 169, 대각 성분 제외 최대값: 3.0723211693007966
# Iteration 170, 대각 성분 제외 최대값: 3.0670110525542698
# Iteration 171, 대각 성분 제외 최대값: 3.079118877003196
# Iteration 172, 대각 성분 제외 최대값: 3.0737654510911336
# Iteration 173, 대각 성분 제외 최대값: 3.0854719203672496
# Iteration 174, 대각 성분 제외 최대값: 3.0800836644998544
# Iteration 175, 대각 성분 제외 최대값: 3.0914153392868218
# Iteration 176, 대각 성분 제외 최대값: 3.0860022262102262
# Iteration 177, 대각 성분 제외 최대값: 3.096980902721457
# Iteration 178, 대각 성분 제외 최대값: 3.0915538998819545
# Iteration 179, 대각 성분 제외 최대값: 3.1021974633383307
# Iteration 180, 대각 성분 제외 최대값: 3.0967681287320903
# Iteration 181, 대각 성분 제외 최대값: 3.1070912686547203
# Iteration 182, 대각 성분 제외 최대값: 3.1016714253072535
# Iteration 183, 대각 성분 제외 최대값: 3.111686234561783
# Iteration 184, 대각 성분 제외 최대값: 3.1062877102997373
# Iteration 185, 대각 성분 제외 최대값: 3.1160041862510353
# Iteration 186, 대각 성분 제외 최대값: 3.1106386076756793
# Iteration 187, 대각 성분 제외 최대값: 3.120065070839329
# Iteration 188, 대각 성분 제외 최대값: 3.1147437022692053
# Iteration 189, 대각 성분 제외 최대값: 3.123887145374507
# Iteration 190, 대각 성분 제외 최대값: 3.1186207650634903
# Iteration 191, 대각 성분 제외 최대값: 3.127487143384057
# Iteration 192, 대각 성분 제외 최대값: 3.1222859505962606
# Iteration 193, 대각 성분 제외 최대값: 3.1308804226876865
# Iteration 194, 대각 성분 제외 최대값: 3.1257539702692774
# Iteration 195, 대각 성분 제외 최대값: 3.1340810968195707
# Iteration 196, 대각 성분 제외 최대값: 3.1290382447873086
# Iteration 197, 대각 성분 제외 최대값: 3.137102152086156
# Iteration 198, 대각 성분 제외 최대값: 3.1321510384846882
# Iteration 199, 대각 성분 제외 최대값: 3.1399555520124602

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier as knc

# %%
knn = knc(n_neighbors=1)
knn_w = knc(n_neighbors=1)

# %%
knn.fit(X_train, y_train)
knn_w.fit(X_train_w, y_train_w)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
y_pred = knn.predict(X_test)
y_pred_w = knn_w.predict(X_test_w)
# Out:
# c:\Users\wjdgh\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] 지정된 파일을 찾을 수 없습니다
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\wjdgh\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "c:\Users\wjdgh\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\wjdgh\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\wjdgh\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %% [markdown]
# # Results
# #### -F1 score를 각 채점 항목 별로 출력하면 됩니다

# %%
from sklearn.metrics import f1_score

# %%
print(f"Naive PCA: {f1_score(y_test, y_pred)}\nWhitening PCA: {f1_score(y_test_w, y_pred_w)}")
# Out:
# Naive PCA: 0.43902439024390244
# Whitening PCA: 0.65
